# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
voos = sns.load_dataset('flights')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5709/1721081612.py in <module>
# ----> 1 voos = sns.load_dataset('flights')
#
# NameError: name 'sns' is not defined

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
flights = sns.load_dataset('flights')

# %%
tips.describe()
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
plt.plot(data=flights)
# Out:
# []

# %%
pvt_flights = flights.pivot_table(values='passengers', index='month', columns='year')

# %%
sns.heatmap(pvt_flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(pvt_flights)
