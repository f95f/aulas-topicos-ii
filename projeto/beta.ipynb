# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
occurrences = pd.read_csv('./database/ocorrencia.csv', delimiter=';')
occurrences
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  86683               86683               86683
# 1                  86682               86682               86682
# 2                  86678               86678               86678
# 3                  86677               86677               86677
# 4                  86676               86676               86676
# ...                  ...                 ...                 ...
# 12871              28377               28377               28377
# 12872              28375               28375               28375
# 12873              28355               28355               28355
# 12874              28335               28335               28335
# 12875              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   86683               86683          INCIDENTE GRAVE
# ...

# %%
airplanes = pd.read_csv('./database/aeronave.csv', delimiter=';')
airplanes
# Out:
#        codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                   86683              PRZND                         ***
# 1                   86682              PRDHL                         ***
# 2                   86678              PRBGU                         ***
# 3                   86677              PRJKK                         ***
# 4                   86676              PTWAH                         ***
# ...                   ...                ...                         ...
# 12984               28377              PTDOJ                         ***
# 12985               28375              PRMMS                         ***
# 12986               28355              PTAFV                         ***
# 12987               28335              PRJCR                         ***
# 12988               28256              PTUKG                         ***
#
#       aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
occurrences_complete = pd.merge(occurrences, airplanes, on=['codigo_ocorrencia2'])
occurrences_complete
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  86683               86683               86683
# 1                  86682               86682               86682
# 2                  86678               86678               86678
# 3                  86677               86677               86677
# 4                  86676               86676               86676
# ...                  ...                 ...                 ...
# 12984              28377               28377               28377
# 12985              28375               28375               28375
# 12986              28355               28355               28355
# 12987              28335               28335               28335
# 12988              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   86683               86683          INCIDENTE GRAVE
# ...

# %%
occurrences_complete
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  86683               86683               86683
# 1                  86682               86682               86682
# 2                  86678               86678               86678
# 3                  86677               86677               86677
# 4                  86676               86676               86676
# ...                  ...                 ...                 ...
# 12984              28377               28377               28377
# 12985              28375               28375               28375
# 12986              28355               28355               28355
# 12987              28335               28335               28335
# 12988              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   86683               86683          INCIDENTE GRAVE
# ...

# %%
occurrences_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12989 entries, 0 to 12988
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               12989 non-null  int64
#  1   codigo_ocorrencia1              12989 non-null  int64
#  2   codigo_ocorrencia2              12989 non-null  int64
#  3   codigo_ocorrencia3              12989 non-null  int64
#  4   codigo_ocorrencia4              12989 non-null  int64
#  5   ocorrencia_classificacao        12989 non-null  object
#  6   ocorrencia_latitude             10236 non-null  object
#  7   ocorrencia_longitude            10236 non-null  object
#  8   ocorrencia_cidade               12989 non-null  object
#  9   ocorrencia_uf                   12989 non-null  object
#  10  ocorrencia_pais                 12989 non-null  object
#  11  ocorrencia_aerodromo            12989 non-null  object
# ...

# %%
sns.barplot(x='ocorrencia_uf', y='aeronave_nivel_dano', hue='aeronave_nivel_dano', data=occurrences_complete)
# Out:
# <Axes: xlabel='ocorrencia_uf', ylabel='aeronave_nivel_dano'>

# %%
occurrence_type = pd.read_csv('./database/ocorrencia_tipo.csv', delimiter=';')
contributing_factor = pd.read_csv('./database/fator_contribuinte.csv', delimiter=';')
recommendation = pd.read_csv('./database/recomendacao.csv', delimiter=';')

# %%
recommendation
# Out:
#       codigo_ocorrencia4          recomendacao_numero  \
# 0                  83193       A-014/CENIPA/2024 - 01
# 1                  83193       A-014/CENIPA/2024 - 02
# 2                  82458       A-146/CENIPA/2023 - 01
# 3                  82458       A-146/CENIPA/2023 - 02
# 4                  81937       A-121/CENIPA/2023 - 01
# ...                  ...                          ...
# 3566               28355                     030/D/10
# 3567               28355                     030/D/10
# 3568               28335  A-169/CENIPA/2013 - RSV 001
# 3569               28256                     437/2012
# 3570               28256                     438/2012
#
#      recomendacao_dia_assinatura recomendacao_dia_encaminhamento  \
# 0                     2025-02-17                      2025-02-19
# 1                     2025-02-17                      2025-02-19
# 2                     2025-03-13                      2025-03-06
# ...

# %%
occurrences_complete = pd.merge(occurrences_complete, contributing_factor, on=['codigo_ocorrencia3'])

# %%
occurrences_complete = pd.merge(occurrences_complete, occurrence_type, on=['codigo_ocorrencia1'])

# %%
occurrences_complete = pd.merge(occurrences_complete, recommendation, on=['codigo_ocorrencia4'])

# %%
occurrences_complete.info()

# %%
sns.barplot(x='ocorrencia_uf', y='aeronave_nivel_dano', hue='taxonomia_tipo_icao', data=occurrences_complete)
# Out:
# <AxesSubplot:xlabel='ocorrencia_uf', ylabel='aeronave_nivel_dano'>

# %%
occurrences_complete.corr(numeric_only=True)
sns.heatmap(occurrences_complete.corr(numeric_only=True), annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_34424/743040984.py in <module>
# ----> 1 occurrences_complete.corr(numeric_only=True)
#       2 sns.heatmap(occurrences_complete.corr(numeric_only=True), annot=True)
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'numeric_only'

# %%
plt.plot(data=airplanes)
# Out:
# []

# %%
airplanes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12989 entries, 0 to 12988
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   codigo_ocorrencia2           12989 non-null  int64
#  1   aeronave_matricula           12988 non-null  object
#  2   aeronave_operador_categoria  12980 non-null  object
#  3   aeronave_tipo_veiculo        12988 non-null  object
#  4   aeronave_fabricante          12985 non-null  object
#  5   aeronave_modelo              12980 non-null  object
#  6   aeronave_tipo_icao           12979 non-null  object
#  7   aeronave_motor_tipo          12573 non-null  object
#  8   aeronave_motor_quantidade    12988 non-null  object
#  9   aeronave_pmd                 12988 non-null  float64
#  10  aeronave_pmd_categoria       12988 non-null  float64
#  11  aeronave_assentos            11864 non-null  float64
# ...

# %%
print(airplanes)
# Out:
#        codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                   86683              PRZND                         ***
# 1                   86682              PRDHL                         ***
# 2                   86678              PRBGU                         ***
# 3                   86677              PRJKK                         ***
# 4                   86676              PTWAH                         ***
# ...                   ...                ...                         ...
# 12984               28377              PTDOJ                         ***
# 12985               28375              PRMMS                         ***
# 12986               28355              PTAFV                         ***
# 12987               28335              PRJCR                         ***
# 12988               28256              PTUKG                         ***
#
#       aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
airplanes.tail(54)
# Out:
#        codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 12935               29860              PTMFK                         ***
# 12936               29859              PRMBK                         ***
# 12937               29858              PTJOH                  PARTICULAR
# 12938               29855              PPMJQ                         ***
# 12939               29796              PTLQH                         ***
# 12940               29795              PTWOU                  PARTICULAR
# 12941               29776              PRFAG               ESPECIALIZADA
# 12942               29775              PTIAT                  PARTICULAR
# 12943               29736              PTVPK                         ***
# 12944               29735              PTWBZ                         ***
# 12945               29715              PTWLD                  PARTICULAR
# 12946               29678              PRBRK                         ***
# ...

# %%
airplanes['aeronave_nivel_dano'].unique()
# Out:
# array(['LEVE', 'NENHUM', 'SUBSTANCIAL', 'DESTRUÍDA', '***', nan],
#       dtype=object)

# %%
airplanes['aeronave_registro_segmento'].unique()
# Out:
# array(['***', nan, 'REGULAR', 'NÃO REGULAR', 'PARTICULAR', 'AGRÍCOLA',
#        'ESPECIALIZADA', 'INSTRUÇÃO', 'EXPERIMENTAL', 'TÁXI AÉREO',
#        'ADMINISTRAÇÃO DIRETA', 'ADMINISTRAÇÃO INDIRETA', 'MÚLTIPLA',
#        'HISTÓRICA'], dtype=object)

# %%
print(occurrences_complete)
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  83193               83193               83193
# 1                  83193               83193               83193
# 2                  83193               83193               83193
# 3                  83193               83193               83193
# 4                  83193               83193               83193
# ...                  ...                 ...                 ...
# 23251              28256               28256               28256
# 23252              28256               28256               28256
# 23253              28256               28256               28256
# 23254              28256               28256               28256
# 23255              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   83193               83193                 ACIDENTE
# ...

# %%
sns.heatmap(airplanes.isnull())
# Out:
# <AxesSubplot:>

# %%
airplanes.isnull().sum()
# Out:
# codigo_ocorrencia2                0
# aeronave_matricula                1
# aeronave_operador_categoria       9
# aeronave_tipo_veiculo             1
# aeronave_fabricante               4
# aeronave_modelo                   9
# aeronave_tipo_icao               10
# aeronave_motor_tipo             416
# aeronave_motor_quantidade         1
# aeronave_pmd                      1
# aeronave_pmd_categoria            1
# aeronave_assentos              1125
# aeronave_ano_fabricacao         889
# aeronave_pais_fabricante          1
# aeronave_pais_registro            1
# aeronave_registro_categoria       1
# aeronave_registro_segmento       19
# aeronave_voo_origem               6
# aeronave_voo_destino              4
# aeronave_fase_operacao            1
# aeronave_tipo_operacao            1
# aeronave_nivel_dano               1
# aeronave_fatalidades_total        1
# dtype: int64

# %%
airplanes['aeronave_tipo_operacao'].unique()
# Out:
# array(['EXPERIMENTAL', 'POLICIAL', 'TÁXI AÉREO', 'PRIVADA', 'INSTRUÇÃO',
#        '***', 'REGULAR', 'AGRÍCOLA', 'ESPECIALIZADA', 'AERODESPORTIVA',
#        'NÃO REGULAR', nan], dtype=object)

# %%
airplanes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12989 entries, 0 to 12988
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   codigo_ocorrencia2           12989 non-null  int64
#  1   aeronave_matricula           12988 non-null  object
#  2   aeronave_operador_categoria  12980 non-null  object
#  3   aeronave_tipo_veiculo        12988 non-null  object
#  4   aeronave_fabricante          12985 non-null  object
#  5   aeronave_modelo              12980 non-null  object
#  6   aeronave_tipo_icao           12979 non-null  object
#  7   aeronave_motor_tipo          12573 non-null  object
#  8   aeronave_motor_quantidade    12988 non-null  object
#  9   aeronave_pmd                 12988 non-null  float64
#  10  aeronave_pmd_categoria       12988 non-null  float64
#  11  aeronave_assentos            11864 non-null  float64
# ...

# %% [raw]
# occurrences_complete.info()

# %%
occurrences_complete.nunique()
# Out:
# codigo_ocorrencia                  1267
# codigo_ocorrencia1                 1267
# codigo_ocorrencia2                 1267
# codigo_ocorrencia3                 1267
# codigo_ocorrencia4                 1267
# ocorrencia_classificacao              3
# ocorrencia_latitude                1044
# ocorrencia_longitude               1038
# ocorrencia_cidade                   604
# ocorrencia_uf                        27
# ocorrencia_pais                       1
# ocorrencia_aerodromo                261
# ocorrencia_dia                     1122
# ocorrencia_hora                     365
# investigacao_aeronave_liberada        2
# investigacao_status                   2
# divulgacao_relatorio_numero        1237
# divulgacao_relatorio_publicado        2
# divulgacao_dia_publicacao           283
# total_recomendacoes                  23
# total_aeronaves_envolvidas            2
# ocorrencia_saida_pista                2
# aeronave_matricula                 1220
# ...

# %%
airplanes['fator_area'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/lib/python3/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/lib/python3/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fator_area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
occurrences_complete.info()

# %%
occurrences_complete.isnull().sum()

# %%
print(table_info)
# Out:
# <bound method DataFrame.info of        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  83193               83193               83193
# 1                  83193               83193               83193
# 2                  83193               83193               83193
# 3                  83193               83193               83193
# 4                  83193               83193               83193
# ...                  ...                 ...                 ...
# 23251              28256               28256               28256
# 23252              28256               28256               28256
# 23253              28256               28256               28256
# 23254              28256               28256               28256
# 23255              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   83193               83193                 ACIDENTE
# ...

# %%
sns.pairplot(airplanes, hue="aeronave_nivel_dano")

# %%
occurrences_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23256 entries, 0 to 23255
# Data columns (total 59 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   codigo_ocorrencia                23256 non-null  int64
#  1   codigo_ocorrencia1               23256 non-null  int64
#  2   codigo_ocorrencia2               23256 non-null  int64
#  3   codigo_ocorrencia3               23256 non-null  int64
#  4   codigo_ocorrencia4               23256 non-null  int64
#  5   ocorrencia_classificacao         23256 non-null  object
#  6   ocorrencia_latitude              23256 non-null  object
#  7   ocorrencia_longitude             23256 non-null  object
#  8   ocorrencia_cidade                23256 non-null  object
#  9   ocorrencia_uf                    23256 non-null  object
#  10  ocorrencia_pais                  23256 non-null  object
#  11  ocorrencia_aerodromo             23256 non-null  object
# ...
